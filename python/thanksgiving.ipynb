# %%
import numpy as np
import pandas as pd

data=pd.read_csv("thank.csv")
data.head(3)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
# 2                                Roasted
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# ...

# %%
df1=pd.read_excel("thanks.xlsx")
df1

# %% [markdown]
# how muc ttoal........ value counts
#
# $25,000 to $49,999      180
#
# Prefer not to answer    136
#
# $50,000 to $74,999      135
#
# $75,000 to $99,999      133
#
# $100,000 to $124,999    111
#
# $200,000 and up          80
#
# $10,000 to $24,999       68
#
# $0 to $9,999             66
#
# $125,000 to $149,999     49
#
# $150,000 to $174,999     40
#
# $175,000 to $199,999     27
#
# Name: How much total combined money did all members of your HOUSEHOLD earn last year?, dtype: int64
#
#
# remove dollar
# remove to
#
# for 200000 and up      ko 20000 bna dneege
#
#
# for $75,000 to $99,999    inko numeric bna denge
#
#
# for prefer not to answer     Nan

# %%
# Q1 Write a function to change the How much.....
# to a single numeric value and store in a new column
# income

# %%
import math
def clean_income(value):
    if value == "$200,000 and up":
        return 200000
    elif value == "Prefer not to answer":
        return np.nan
    elif isinstance(value, float) and math.isnan(value):
        return np.nan
    else:
        value = value.replace(",", "")
        value=value.replace(" to ", "")
        low=value[value.find("$")+1:value.find("$",1)]
        high=value[value.find("$",2)+1:]
        value=(int(high)+int(low))/2
    return value
                                         
                                           
data["income"] = data["How much total combined money did all members of your HOUSEHOLD earn last year?"].apply(clean_income)
data["income"]
# Out:
# 0        87499.5
# 1        62499.5
# 2         4999.5
# 3       200000.0
# 4       112499.5
#           ...
# 1053    112499.5
# 1054     62499.5
# 1055    112499.5
# 1056         NaN
# 1057         NaN
# Name: income, Length: 980, dtype: float64

# %%
data["How much total combined money did all members of your HOUSEHOLD earn last year?"].unique()
# Out:
# array(['$75,000 to $99,999', '$50,000 to $74,999', '$0 to $9,999',
#        '$200,000 and up', '$100,000 to $124,999', '$25,000 to $49,999',
#        'Prefer not to answer', '$10,000 to $24,999',
#        '$175,000 to $199,999', '$150,000 to $174,999',
#        '$125,000 to $149,999', nan], dtype=object)

# %%
def clean_income(value):
    if value == "$200,000 and up":
        return 200000
    elif value == "Prefer not to answer":
        return np.nan
    elif isinstance(value, float) :
        return np.nan
    else:
        value = value.replace(",", "").replace("$",'')
        income_high, income_low = value.split(" to ")
    return (int(income_high) + int(income_low)) / 2 
    
                                         
                                           
data["income"] = data["How much total combined money did all members of your HOUSEHOLD earn last year?"].apply(clean_income)
data["income"].head(15)
# Out:
# 0      87499.5
# 1      62499.5
# 2       4999.5
# 3     200000.0
# 4     112499.5
# 5       4999.5
# 6      37499.5
# 7          NaN
# 8      87499.5
# 9      37499.5
# 11     37499.5
# 12      4999.5
# 13      4999.5
# 14     62499.5
# 15    200000.0
# Name: income, dtype: float64

# %%
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
# Q2 make different dataframes for various ranges of age
# names as df45,df60,df30

# %%
a1=data["Age"].value_counts()
a1
# Out:
# 45 - 59    286
# 60+        264
# 30 - 44    259
# 18 - 29    216
# Name: Age, dtype: int64

# %%
age=data.groupby('Age').groups
age
# Out:
# {'18 - 29': [0, 1, 2, 5, 6, 7, 12, 13, 17, 21, 22, 23, 25, 27, 32, 37, 38, 39, 40, 41, 44, 46, 47, 48, 54, 60, 69, 70, 71, 72, 74, 75, 78, 79, 82, 84, 91, 100, 102, 104, 108, 111, 115, 119, 123, 124, 129, 131, 135, 137, 139, 146, 164, 165, 170, 188, 194, 195, 197, 207, 211, 232, 236, 244, 246, 247, 248, 250, 260, 262, 264, 265, 266, 272, 274, 280, 284, 287, 291, 299, 302, 309, 315, 321, 328, 331, 338, 343, 345, 347, 363, 370, 372, 374, 389, 393, 396, 417, 418, 420, ...], '30 - 44': [3, 4, 8, 9, 10, 11, 15, 16, 18, 19, 20, 24, 26, 28, 29, 30, 31, 33, 34, 35, 36, 42, 43, 45, 49, 50, 56, 58, 66, 68, 73, 77, 80, 83, 87, 88, 93, 94, 95, 96, 99, 101, 112, 113, 114, 117, 121, 125, 126, 130, 134, 145, 148, 149, 150, 151, 157, 160, 161, 163, 166, 167, 174, 175, 180, 181, 183, 186, 187, 191, 196, 200, 201, 204, 209, 215, 217, 218, 223, 224, 225, 226, 227, 228, 234, 235, 237, 240, 252, 263, 269, 270, 275, 276, 277, 279, 288, 290, 292, 293, ...], '45 - 59': [51, 52, 53, 55, 57, 59, 61, 62, 63, 6
# ...

# %%
age=data.groupby('Age').groups
df18_29=age['18 - 29']
df30_44=age['30 - 44']
df45_59=age["45 - 59"]
df60=age["60+"]

# %%
type(df18_29)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
df18=data.loc[lambda data: data['Age'] =='18 - 29',: ]
df30=data.loc[lambda data: data['Age'] =='30 - 44',: ]
df45=data.loc[lambda data: data['Age'] =='45 - 59',: ]
df60=data.loc[lambda data: data['Age'] =='60+',: ]

# %%
df30
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# 8       4337914977                            Yes
# 9       4337899817                            Yes
# 11      4337893416                            Yes
# ...            ...                            ...
# 1037    4335954207                            Yes
# 1040    4335952833                            Yes
# 1045    4335950654                            Yes
# 1047    4335949169                            Yes
# 1053    4335944082                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 3                                                Turkey
# 4                                              Tofurkey
# 8                                                Turkey
# 9                                Other (please specify)
# 11                                               Turkey
# ...

# %%
d18=data[data["Age"]== '18 - 29']

# %%
d18
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 5       4337929779                            Yes
# 6       4337924420                            Yes
# ...            ...                            ...
# 991     4335974428                            Yes
# 997     4335970729                            Yes
# 1000    4335967669                            Yes
# 1039    4335953888                            Yes
# 1046    4335949486                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 5                                                Turkey
# 6                                                Turkey
# ...

# %%
df18
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 5       4337929779                            Yes
# 6       4337924420                            Yes
# ...            ...                            ...
# 991     4335974428                            Yes
# 997     4335970729                            Yes
# 1000    4335967669                            Yes
# 1039    4335953888                            Yes
# 1046    4335949486                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 5                                                Turkey
# 6                                                Turkey
# ...

# %%
df18_29.where?

# %%
datadf18_29=pd.DataFrame(df18_29.values)
datadf18_29
# Out:
#         0
# 0       0
# 1       1
# 2       2
# 3       5
# 4       6
# ..    ...
# 211  1009
# 212  1032
# 213  1039
# 214  1046
# 215  1052
#
# [216 rows x 1 columns]

# %%
# Q3  there is a column 'What type of cranberry saucedo you typically have?'

# Q group on this column and find the avg of income for these groups
# plot the graph

# %%
# a3=data.groupby(["What type of cranberry saucedo you typically have?"]).count()
# a3

# %%
a4=data["What type of cranberry saucedo you typically have?"].value_counts()
d2=data.groupby("What type of cranberry saucedo you typically have?")

# %%
d2=data.groupby("What type of cranberry saucedo you typically have?")
s=d2["income"].mean()
print(s)
s.plot(kind="bar")
# Out:
# What type of cranberry saucedo you typically have?
# Canned                    83823.403409
# Homemade                  94878.107287
# None                      78886.084034
# Other (please specify)    86629.978261
# Name: income, dtype: float64
# <AxesSubplot:xlabel='What type of cranberry saucedo you typically have?'>

# %%
d3=data.groupby(["What type of cranberry saucedo you typically have?","income"]).mean()
s=d2["income"].mean()
print(s)
d3.plot(kind="bar")
# Out:
# What type of cranberry saucedo you typically have?  income
# Canned                                              4999.5        4999.5
#                                                     17499.5      17499.5
#                                                     37499.5      37499.5
#                                                     62499.5      62499.5
#                                                     87499.5      87499.5
#                                                     112499.5    112499.5
#                                                     137499.5    137499.5
#                                                     162499.5    162499.5
#                                                     187499.5    187499.5
#                                                     200000.0    200000.0
# Homemade                                            4999.5        4999.5
#                                                     17499.5      17499.5
# ...

# %%
d3=data.groupby(["What type of cranberry saucedo you typically have?","income"]).mean()
d3.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='What type of cranberry saucedo you typically have?,income'>

# %%
s
# Out:
# What type of cranberry saucedo you typically have?
# Canned                    123141.125000
# Homemade                  134381.720648
# None                      117772.168067
# Other (please specify)    126846.913043
# Name: income, dtype: float64

# %%
# how would you descirbe where you live......use this column
# Q count the gender wise populaation living in differnt areas (How would you describe where you live? )
# and also eating different typed of main dish How is the main dish typically cooked?

# %%
q1=data.groupby(["How would you describe where you live?","What is your gender?"])["What is your gender?"].count()
q1.plot(kind="bar")

q1
# Out:
# How would you describe where you live?  What is your gender?
# Rural                                   Female                  117
#                                         Male                     99
# Suburban                                Female                  276
#                                         Male                    219
# Urban                                   Female                  122
#                                         Male                    114
# Name: What is your gender?, dtype: int64

# %%
q=data.groupby(["How is the main dish typically cooked? - Other (please specify)","What is your gender?"])["What is your gender?"].count()
q
# Out:
# How is the main dish typically cooked? - Other (please specify)  What is your gender?
#  Cooked in bourbon and then smokes                               Female                  1
# 1 fried 1 roasted                                                Male                    1
# BBQ'd                                                            Female                  1
# Barbecue                                                         Female                  1
# Barbeque                                                         Male                    1
# Broiled                                                          Female                  1
# Cooked on a Weber Charcoal Grill                                 Male                    1
# Fried and one baked                                              Female                  1
# Grilled                                                          Female                  3
# ...

# %%
q=data.groupby(["How would you describe where you live?","How is the main dish typically cooked? - Other (please specify)","What is your gender?"]).count()
q
# Out:
#                                                                                                                 RespondentID  \
# How would you describe where you live? How is the main dish typically cooked? - Other ... What is your gender?
# Rural                                  Cooked on a Weber Charcoal Grill                   Male                             1
#                                        Grilled                                            Female                           2
#                                        Grilled on the Weber                               Female                           1
#                                        Restaurant with various choices.                   Male                             1
#                                        Smoked                                             Female                           3
# ...

# %%
q.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='How is the main dish typically cooked? - Other (please specify),What is your gender?'>

# %%
# Q make a list having mean of income  of differnt categories in column "What type of cranberry saucedo you typically have?"
# by making two differnt data frames
# plot the list on the graph

# %%
d2=data.groupby("What type of cranberry saucedo you typically have?")
s=d2["income"].mean()

# %%
home=data[data["What type of cranberry saucedo you typically have?"]=="Homemade"]
canned=data[data["What type of cranberry saucedo you typically have?"]=="Canned"]
print(home["income"].mean())
print(canned["income"].mean())
# Out:
# 94878.1072874494
# 83823.40340909091

# %%
optional ques ??/change column names

# %%
#make new dataframe
data1=pd.DataFrame(d1)
data1
# Out:
#                       How much total combined money did all members of your HOUSEHOLD earn last year?
# $25,000 to $49,999                                                  180
# Prefer not to answer                                                136
# $50,000 to $74,999                                                  135
# $75,000 to $99,999                                                  133
# $100,000 to $124,999                                                111
# $200,000 and up                                                      80
# $10,000 to $24,999                                                   68
# $0 to $9,999                                                         66
# $125,000 to $149,999                                                 49
# $150,000 to $174,999                                                 40
# $175,000 to $199,999                                                 27

# %%
d2
# Out:
# $25,000 to $49,999      180
# Prefer not to answer    136
# $50,000 to $74,999      135
# $75,000 to $99,999      133
# $100,000 to $124,999    111
# $200,000 and up          80
# $10,000 to $24,999       68
# $0 to $9,999             66
# $125,000 to $149,999     49
# $150,000 to $174,999     40
# $175,000 to $199,999     27
# Name: income, dtype: int64

# %% [markdown]
#  Columns names from the Data Dataframes

# %%
print(data.columns.tolist())
columns = data.columns.tolist()
for col in columns:
    print(col)
# Out:
# ['RespondentID', 'Do you celebrate Thanksgiving?', 'What is typically the main dish at your Thanksgiving dinner?', 'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)', 'How is the main dish typically cooked?', 'How is the main dish typically cooked? - Other (please specify)', 'What kind of stuffing/dressing do you typically have?', 'What kind of stuffing/dressing do you typically have? - Other (please specify)', 'What type of cranberry saucedo you typically have?', 'What type of cranberry saucedo you typically have? - Other (please specify)', 'Do you typically have gravy?', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots', 'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower', 'Which of th
# ...

# %%
# 2: Filtering Out Rows From A DataFrame
# Filter data where : Do you celebrate Thanksgiving? is not Yes
# 2.1 Extract pandas series from the dataframe data :
dyct = data["Do you celebrate Thanksgiving?"]
print(type(dyct))
print("----------------")
print(dyct[0:5])
print("----------------")
print(dyct.value_counts())
print("----------------")
# Out:
# <class 'pandas.core.series.Series'>
# ----------------
# 0    Yes
# 1    Yes
# 2    Yes
# 3    Yes
# 4    Yes
# Name: Do you celebrate Thanksgiving?, dtype: object
# ----------------
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64
# ----------------

# %%
# 2.2 Filter the dataframe data
dyct_yes = data["Do you celebrate Thanksgiving?"] == "Yes"
data = data[dyct_yes]
# # verification :
# print(data["Do you celebrate Thanksgiving?"].value_counts())
data
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 0       4337954960                            Yes
# 1       4337951949                            Yes
# 2       4337935621                            Yes
# 3       4337933040                            Yes
# 4       4337931983                            Yes
# ...            ...                            ...
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 0                                                Turkey
# 1                                                Turkey
# 2                                                Turkey
# 3                                                Turkey
# 4                                              Tofurkey
# ...

# %%
# 3: Using Value_counts To Explore Main Dishes
# 3.1: Display counts of each category
print(data["What is typically the main dish at your Thanksgiving dinner?"].value_counts())
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
tofurkey = data["What is typically the main dish at your Thanksgiving dinner?"] == "Tofurkey"
print(data["Do you typically have gravy?"][tofurkey])
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
filter1 = data["income"] < 150000
rowfiltering = data["How far will you travel for Thanksgiving?"][filter1]
print(rowfiltering.value_counts())
print("---------------------")
filter2 = data["income"] >= 150000
rowfiltering2 = data["How far will you travel for Thanksgiving?"][filter2]
print(rowfiltering2.value_counts())
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64
# ---------------------
# Thanksgiving is happening at my home--I won't travel at all                         66
# Thanksgiving is local--it will take place in the town I live in                     34
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    25
# Thanksgiving is out of town and far away--I have to drive several hours or fly      15
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %%
## What is your gender column mei male and female hai

## we have to change it to 0 and 1

# %%
data["What is your gender?"].value_counts()
data["What is your gender?"]
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 1053    Female
# 1054    Female
# 1055      Male
# 1056       NaN
# 1057       NaN
# Name: What is your gender?, Length: 980, dtype: object

# %%
def gender_code(gender_string):
    if isinstance(gender_string, float) and np.isnan(gender_string):
        return gender_string
    return int(gender_string == "Female")

# %%
data["gender"] = data["What is your gender?"].apply(gender_code)
# data["gender"].value_counts(dropna=False)
data["gender"]
# Out:
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
#        ...
# 1053    1.0
# 1054    1.0
# 1055    0.0
# 1056    NaN
# 1057    NaN
# Name: gender, Length: 980, dtype: float64

# %%
def gen(value):
    if value == "Female":
        return 1
    elif value =="Male":
        return 0
    elif isinstance(value, float) and np.isnan(value):
        return value
data["gender1"] = data["What is your gender?"].apply(gen)
data.head(5)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...
