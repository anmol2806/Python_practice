# %%
import numpy as np

# %% [markdown]
# Q1 - add a new column which should be 20% of residual suagr column<br>
# Q2- create two vectors with some new values of all the columns and add them/concatenate to existing wines table<br>
# Q3- find the sum of all the Columns and add it as last row<br>
# Q4- find all those rows where free sulphur dioxide is between 12 and 15<br>
# Q5- make a new numpy array of above all the data<br>
# Q6- extract records from 5th to tenth row showing information of ph, alcohol and quality<br>
# Q7- find the average of the chlorides, density, sulphate column seperately and plot it on a graph(bar)  storing output in dictionary<br>

# %%
# #q1

# p=wines
# p=np.array(p)
# p1=wines[:,3]*.2
# print(list(list(p1)))
# p1=np.array(p)
# print(p1)
# # print(np.concatenate(p, p1 ))
# # print(p[0:2])
# Out:
# [0.38, 0.52, 0.45999999999999996, 0.38, 0.38, 0.36000000000000004, 0.32000000000000006, 0.24, 0.4, 1.22, 0.36000000000000004, 1.22, 0.32000000000000006, 0.32000000000000006, 0.76, 0.78, 0.36000000000000004, 0.34, 0.8800000000000001, 0.36000000000000004, 0.36000000000000004, 0.45999999999999996, 0.32000000000000006, 0.45999999999999996, 0.48, 0.27999999999999997, 0.36000000000000004, 0.32000000000000006, 0.38, 0.4, 0.48, 0.5, 0.45999999999999996, 2.14, 0.36000000000000004, 1.1, 0.48, 0.42000000000000004, 0.30000000000000004, 1.1800000000000002, 1.1800000000000002, 0.5599999999999999, 0.52, 0.44000000000000006, 0.36000000000000004, 0.42000000000000004, 0.44000000000000006, 0.32000000000000006, 0.32000000000000006, 0.27999999999999997, 0.34, 0.44000000000000006, 0.42000000000000004, 0.6000000000000001, 0.5599999999999999, 0.76, 0.68, 1.02, 0.45999999999999996, 0.48, 0.44000000000000006, 0.36000000000000004, 0.38, 0.4, 0.9300000000000002, 0.9300000000000002, 0.30000000000000004, 0.320000
# ...

# %%
import csv
wines=np.genfromtxt("wines\winequality-red.csv", delimiter=";",skip_header=1)

wines[1:5,1:5]
residualsugar_20 = wines[:,3]*0.20
wines = np.append(wines, residualsugar_20.reshape(1599,1),axis=1)
wines[0:1000]
# Out:
# array([[ 7.4 ,  0.7 ,  0.  , ...,  9.4 ,  5.  ,  0.38],
#        [ 7.8 ,  0.88,  0.  , ...,  9.8 ,  5.  ,  0.52],
#        [ 7.8 ,  0.76,  0.04, ...,  9.8 ,  5.  ,  0.46],
#        ...,
#        [ 5.6 ,  0.66,  0.  , ..., 12.8 ,  7.  ,  0.44],
#        [ 8.9 ,  0.84,  0.34, ...,  9.1 ,  6.  ,  0.28],
#        [ 6.4 ,  0.69,  0.  , ..., 12.9 ,  6.  ,  0.33]])

# %%
#q1

import numpy as np
csvf = np.genfromtxt("wines\winequality-red.csv",delimiter = ";",skip_header = 1)
csvf[1:5,1:5]
residualsugar_20 = csvf[:,3]*0.20
print(residualsugar_20.shape)
csvf = np.append(csvf, residualsugar_20.reshape(1599,1),axis=1)

csvf
# Out:
# (1599,)
# array([[ 7.4  ,  0.7  ,  0.   , ...,  9.4  ,  5.   ,  0.38 ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  9.8  ,  5.   ,  0.52 ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  9.8  ,  5.   ,  0.46 ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ..., 11.   ,  6.   ,  0.46 ],
#        [ 5.9  ,  0.645,  0.12 , ..., 10.2  ,  5.   ,  0.4  ],
#        [ 6.   ,  0.31 ,  0.47 , ..., 11.   ,  6.   ,  0.72 ]])

# %%
import pandas as pd
import csv
df=pd.read_csv("wines\winequality-red.csv",sep=";")
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#q2
vector1 = np.array([11.2,0.28,0.56,1.9,0.075,17.0,60.0,0.9980,3.16,0.58,9.8,6,0.46])
vector2 = np.array([7.4,0.70,0.00,1.9,0.076,11.0,34.0,0.9978,3.51,0.56,9.4,5,0.56])
newvector = np.vstack((vector1,vector2))
wines = np.vstack((wines,newvector))
wines
# Out:
# array([[ 7.4 ,  0.7 ,  0.  , ...,  9.4 ,  5.  ,  0.38],
#        [ 7.8 ,  0.88,  0.  , ...,  9.8 ,  5.  ,  0.52],
#        [ 7.8 ,  0.76,  0.04, ...,  9.8 ,  5.  ,  0.46],
#        ...,
#        [ 7.4 ,  0.7 ,  0.  , ...,  9.4 ,  5.  ,  0.56],
#        [11.2 ,  0.28,  0.56, ...,  9.8 ,  6.  ,  0.46],
#        [ 7.4 ,  0.7 ,  0.  , ...,  9.4 ,  5.  ,  0.56]])

# %%
#q3
colsum = np.sum(wines,axis = 0)
print(colsum)
wines2 = np.vstack((wines,colsum))
wines2
# Out:
# [13321.7       844.965     433.85     4063.35      140.01    25412.
#  74396.       1595.79374  5301.14     1053.52    16685.55     9023.
#    812.93   ]
# array([[7.400000e+00, 7.000000e-01, 0.000000e+00, ..., 9.400000e+00,
#         5.000000e+00, 3.800000e-01],
#        [7.800000e+00, 8.800000e-01, 0.000000e+00, ..., 9.800000e+00,
#         5.000000e+00, 5.200000e-01],
#        [7.800000e+00, 7.600000e-01, 4.000000e-02, ..., 9.800000e+00,
#         5.000000e+00, 4.600000e-01],
#        ...,
#        [1.120000e+01, 2.800000e-01, 5.600000e-01, ..., 9.800000e+00,
#         6.000000e+00, 4.600000e-01],
#        [7.400000e+00, 7.000000e-01, 0.000000e+00, ..., 9.400000e+00,
#         5.000000e+00, 5.600000e-01],
#        [1.332170e+04, 8.449650e+02, 4.338500e+02, ..., 1.668555e+04,
#         9.023000e+03, 8.129300e+02]])

# %%
#q4
for i in range(1601):
    if 12<wines[i,5]<15:
        print(i)
        print(wines[i])
# Out:
# 5
# [ 7.4     0.66    0.      1.8     0.075  13.     40.      0.9978  3.51
#   0.56    9.4     5.      0.36  ]
# (13,)
# 28
# [ 7.1     0.71    0.      1.9     0.08   14.     35.      0.9972  3.47
#   0.55    9.4     5.      0.38  ]
# (13,)
# 34
# [ 5.2     0.32    0.25    1.8     0.103  13.     50.      0.9957  3.38
#   0.55    9.2     5.      0.36  ]
# (13,)
# 37
# [ 8.1     0.38    0.28    2.1     0.066  13.     30.      0.9968  3.23
#   0.73    9.7     7.      0.42  ]
# (13,)
# 63
# [7.000e+00 7.350e-01 5.000e-02 2.000e+00 8.100e-02 1.300e+01 5.400e+01
#  9.966e-01 3.390e+00 5.700e-01 9.800e+00 5.000e+00 4.000e-01]
# (13,)
# 77
# [ 6.8     0.785   0.      2.4     0.104  14.     30.      0.9966  3.52
#   0.55   10.7     6.      0.48  ]
# (13,)
# 99
# [ 8.1     0.545   0.18    1.9     0.08   13.     35.      0.9972  3.3
#   0.59    9.      6.      0.38  ]
# (13,)
# 102
# [ 8.1     0.545   0.18    1.9     0.08   13.     35.      0.9972  3.3
#   0.59    9.      6.      0.38  ]
# ...

# %%
#or q4
x=wines[(wines[:,5] > 12) & (wines[:,5] < 15)]
x.shape
# Out:
# (107, 13)

# %%
#q6
wines[5:11,[8,10,11]]
# Out:
# array([[ 3.51,  9.4 ,  5.  ],
#        [ 3.3 ,  9.4 ,  5.  ],
#        [ 3.39, 10.  ,  7.  ],
#        [ 3.36,  9.5 ,  7.  ],
#        [ 3.35, 10.5 ,  5.  ],
#        [ 3.28,  9.2 ,  5.  ]])

# %%
#q7
from matplotlib import pyplot as plt
avgc = np.mean(wines[:,4])
avgd = np.mean(wines[:,7])
avgs = np.mean(wines[:,9])
dict1={}
dict1['Chlorides'] = avgc
dict1['density'] = avgd
dict1['sulphates'] = avgs
print(dict1)
plt.bar(dict1.keys(),dict1.values())
plt.xlabel("Chemicals")
plt.ylabel("Average")
plt.show()





#pandas
avg_chloride = np.mean(df['chlorides'])
avg_density = np.mean(df['density'])
avg_sulphate = np.mean(df['sulphates'])
d = {}
d['chlorides'] = avg_chloride
d['density'] = avg_density
d['sulphate'] = avg_sulphate
# Out:
# {'Chlorides': 0.08746654158849279, 'density': 0.9967466791744841, 'sulphates': 0.6581488430268917}

# %%
#q5
wines
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  9.4  ,  5.   ,  0.38 ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  9.8  ,  5.   ,  0.52 ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  9.8  ,  5.   ,  0.46 ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ..., 11.   ,  6.   ,  0.46 ],
#        [ 5.9  ,  0.645,  0.12 , ..., 10.2  ,  5.   ,  0.4  ],
#        [ 6.   ,  0.31 ,  0.47 , ..., 11.   ,  6.   ,  0.72 ]])

# %% [markdown]
# ## Practice

# %%
wines[:,11]==5
# Out:
# array([ True,  True,  True, ..., False,  True, False])

# %%
#rows which have quality equal to 5
wines[wines[:,11]==5]
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  9.4  ,  5.   ,  0.38 ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  9.8  ,  5.   ,  0.52 ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  9.8  ,  5.   ,  0.46 ],
#        ...,
#        [ 6.6  ,  0.725,  0.2  , ...,  9.2  ,  5.   ,  1.56 ],
#        [ 6.2  ,  0.6  ,  0.08 , ..., 10.5  ,  5.   ,  0.4  ],
#        [ 5.9  ,  0.645,  0.12 , ..., 10.2  ,  5.   ,  0.4  ]])

# %%
wines[wines[:,11]==5].shape
# Out:
# (681, 13)

# %%
#for high quality
x1= wines[:,11]>7
print(wines[x1,:])
print(wines[x1,:][:3,:])
# Out:
# [[7.9000e+00 3.5000e-01 4.6000e-01 3.6000e+00 7.8000e-02 1.5000e+01
#   3.7000e+01 9.9730e-01 3.3500e+00 8.6000e-01 1.2800e+01 8.0000e+00
#   7.2000e-01]
#  [1.0300e+01 3.2000e-01 4.5000e-01 6.4000e+00 7.3000e-02 5.0000e+00
#   1.3000e+01 9.9760e-01 3.2300e+00 8.2000e-01 1.2600e+01 8.0000e+00
#   1.2800e+00]
#  [5.6000e+00 8.5000e-01 5.0000e-02 1.4000e+00 4.5000e-02 1.2000e+01
#   8.8000e+01 9.9240e-01 3.5600e+00 8.2000e-01 1.2900e+01 8.0000e+00
#   2.8000e-01]
#  [1.2600e+01 3.1000e-01 7.2000e-01 2.2000e+00 7.2000e-02 6.0000e+00
#   2.9000e+01 9.9870e-01 2.8800e+00 8.2000e-01 9.8000e+00 8.0000e+00
#   4.4000e-01]
#  [1.1300e+01 6.2000e-01 6.7000e-01 5.2000e+00 8.6000e-02 6.0000e+00
#   1.9000e+01 9.9880e-01 3.2200e+00 6.9000e-01 1.3400e+01 8.0000e+00
#   1.0400e+00]
#  [9.4000e+00 3.0000e-01 5.6000e-01 2.8000e+00 8.0000e-02 6.0000e+00
#   1.7000e+01 9.9640e-01 3.1500e+00 9.2000e-01 1.1700e+01 8.0000e+00
#   5.6000e-01]
# ...

# %%
print(wines[x1,:][:3,:])
print(wines[x1,:][:3,:][0:1,2])
# Out:
# [[7.900e+00 3.500e-01 4.600e-01 3.600e+00 7.800e-02 1.500e+01 3.700e+01
#   9.973e-01 3.350e+00 8.600e-01 1.280e+01 8.000e+00 7.200e-01]
#  [1.030e+01 3.200e-01 4.500e-01 6.400e+00 7.300e-02 5.000e+00 1.300e+01
#   9.976e-01 3.230e+00 8.200e-01 1.260e+01 8.000e+00 1.280e+00]
#  [5.600e+00 8.500e-01 5.000e-02 1.400e+00 4.500e-02 1.200e+01 8.800e+01
#   9.924e-01 3.560e+00 8.200e-01 1.290e+01 8.000e+00 2.800e-01]]
# [0.46]

# %%
highquality_and_alcohal =  (wines[:,10]>12) & (wines[:,11]>7)
print(highquality_and_alcohal)
highquality_and_alcohal1 =  wines[(wines[:,10]>12) & (wines[:,11]>7)]
print(highquality_and_alcohal1)
# Out:
# [False False False ... False False False]
# [[7.9000e+00 3.5000e-01 4.6000e-01 3.6000e+00 7.8000e-02 1.5000e+01
#   3.7000e+01 9.9730e-01 3.3500e+00 8.6000e-01 1.2800e+01 8.0000e+00
#   7.2000e-01]
#  [1.0300e+01 3.2000e-01 4.5000e-01 6.4000e+00 7.3000e-02 5.0000e+00
#   1.3000e+01 9.9760e-01 3.2300e+00 8.2000e-01 1.2600e+01 8.0000e+00
#   1.2800e+00]
#  [5.6000e+00 8.5000e-01 5.0000e-02 1.4000e+00 4.5000e-02 1.2000e+01
#   8.8000e+01 9.9240e-01 3.5600e+00 8.2000e-01 1.2900e+01 8.0000e+00
#   2.8000e-01]
#  [1.1300e+01 6.2000e-01 6.7000e-01 5.2000e+00 8.6000e-02 6.0000e+00
#   1.9000e+01 9.9880e-01 3.2200e+00 6.9000e-01 1.3400e+01 8.0000e+00
#   1.0400e+00]
#  [5.0000e+00 4.2000e-01 2.4000e-01 2.0000e+00 6.0000e-02 1.9000e+01
#   5.0000e+01 9.9170e-01 3.7200e+00 7.4000e-01 1.4000e+01 8.0000e+00
#   4.0000e-01]
#  [7.8000e+00 5.7000e-01 9.0000e-02 2.3000e+00 6.5000e-02 3.4000e+01
#   4.5000e+01 9.9417e-01 3.4600e+00 7.4000e-01 1.2700e+01 8.0000e+00
#   4.6000e-01]
# ...

# %%
#set the value  to 20  for all columns 10 and 11 where
#those rows where alcohol is greater than 10 and 
#quality greater than 7
wines[(wines[:,10]>12) & (wines[:,11]>7)]=20
wines[highquality_and_alcohal,10:]
# Out:
# array([[20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.],
#        [20., 20., 20.]])
